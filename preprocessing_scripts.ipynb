# %% [markdown]
# # Dataset preprocessing

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk
from langdetect import detect
import re, string, unicodedata
import inflect
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer
import datetime
# Out:
# C:\Users\b.eskili\AppData\Local\Continuum\anaconda3\lib\site-packages\PIL\Image.py:82: RuntimeWarning: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 5.3.0
# Pillow version: 5.1.0
#   warnings.warn(str(v), RuntimeWarning)

# %% [markdown]
# ### Convert the raw dataset to dataframe

# %%
## Read text file
filename = 'raw_content/text_content_web.txt'
with open(filename, 'r', encoding="utf-8") as myfile:
    data = myfile.read()
myfile.close()


## split into websites
document = data.split("\n\nNEW WEBSITE\n\n") 

##create list of dataframe columns
website = []
content = []
mcc = []

for doc in document:
    splitted = doc.split(",")
    if len(splitted) >= 3:
        website.append(splitted[0][1:])
        mcc.append(int(splitted[1]))
        content.append(" ".join(splitted[2:]))

# %%
docs = {'website': website ,'mcc': mcc,  'content': content}

documents = pd.DataFrame(docs, columns = ['website', 'mcc', 'content'])

# %% [markdown]
# #### Read the data file

# %%
documents = pd.read_csv("dataset_frame.csv")

# %% [markdown]
# ## Cleaning the text content (sample dataset)
# ###### tokenization, empty string, lower case, special characters

# %%
def remove_non_ascii(words):

    """Remove non-ASCII characters from list of tokenized words"""

    new_words = []

    for word in words:

        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')

        new_words.append(new_word)

    return new_words


def remove_punctuation(words):

    """Remove punctuation from list of tokenized words"""

    new_words = []

    for word in words:

        new_word = re.sub(r'[^\w\s]', ' ', word)

        if new_word != '' and new_word != " ":

            new_words.append(new_word)

    return new_words



stop_words = stopwords.words('english')

def remove_stopwords(doc):

    """Remove stop words from list of tokenized words"""
    for word in stop_words:
      
        doc = doc.replace(" "+word+" ", ' ')
        
    return doc



def stem_words(words):

    """Stem words in list of tokenized words"""

    stemmer = LancasterStemmer()

    stems = []

    for word in words:

        stem = stemmer.stem(word)

        stems.append(stem)

    return stems



def lemmatize_verbs(words):

    """Lemmatize verbs in list of tokenized words"""

    lemmatizer = WordNetLemmatizer()

    lemmas = []

    for word in words:

        lemma = lemmatizer.lemmatize(word, pos='v')

        lemmas.append(lemma)

    return lemmas

# %%
def isLatin(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

    
def clean_data(content):
    content_str = str(content)   #convert content from object type to string
    words = word_tokenize(content_str)
    
    #remove digits, lowercase words
    words = [''.join([i.lower() for i in w if not i.isdigit()]) for w in words]
    
    #remove punctuation
    words = remove_punctuation(words)

    #remove empty strings
    while '' in words:
        words.remove('')
    
    #remove non ascii
    words = remove_non_ascii(words)
    
    #remove stop words   
    #words = [w for w in words if not w in stopwords.words('english')]
    
    #lemmatization
    words = lemmatize_verbs(words)

    doc = " ".join(w for w in words)
    
    #remove stop words
    doc = remove_stopwords(doc)
    
    print("balloon ", datetime.datetime.now() )
    
    return doc

# %% [markdown]
# #### Language filter

# %%
from langdetect import detect


def filter_en(content):
    try :
        if detect(content) == "en":
            return content
        else:
            return "nan"
    except:
        return "nan"
    
#documents["content"] = documents["content"].apply(filter_en)

# %% [markdown]
# #### Add language column to the dataset

# %%
taal = []

for row in documents.iterrows():
    try:
        taal.append(detect(row[1].content))
        #print(detect(row[1].content))
    except:
        taal.append("none")

# %% [markdown]
# #### Save the preprocessed data to file

# %%
#save to file
docs.to_csv("dataset_taal.csv", encoding='utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1da9427adf61> in <module>
#       1 #save to file
# ----> 2 docs.to_csv("dataset_taal.csv", encoding='utf-8', index=False)
#
# AttributeError: 'dict' object has no attribute 'to_csv'

# %%
docs = pd.read_csv("dataset_taal.csv")

# %% [markdown]
# ### Add cluster column to dataframe

# %% [markdown]
# #### Read mcc2clusters

# %%
mcc2clusters = {}
with open("mcc2cluster") as f:
    lines = f.read().splitlines()
    for line in lines:
        token = line.split(":")
        
        mcc2clusters[int(token[0])] = token[1]

# %% [markdown]
# #### Add clusters to dataframe

# %%
clusters = []

for row in docs.iterrows():
    code = int(row[1].mcc)
    #print(code)
    try:
        cluster = mcc2clusters[code]
        clusters.append(cluster)
    except:
        #print(code, "unknown")
        clusters.append("unknown")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-25b673f9ada3> in <module>
#       1 clusters = []
#       2
# ----> 3 for row in docs.iterrows():
#       4     code = int(row[1].mcc)
#       5     #print(code)
#
# AttributeError: 'dict' object has no attribute 'iterrows'

# %%
#Add cluster column to dataset

df = pd.DataFrame(clusters)
df = df.rename(columns={0: "cluster"})
docs = pd.concat([docs, df], axis=1, sort=False)

# %% [markdown]
# ### Filter english data

# %%
documents_en = docs[docs.taal == "en"]

# %%
documents_en
# Out:
#                                      website   mcc  \
# 0                     http://www.max-c-e.com  5967
# 1                 http://www.tradacasino.com  7995
# 2                       http://bensbingo.com  7995
# 4                   http://towa-esutenet.com  7298
# 5                     http://www.mi-porn.com  5967
# 7                      http://getdownxxx.com  5967
# 10                     http://www.dezzel.com  7999
# 11                 http://mycharitybingo.com  7995
# 12                  http://www.Resumenow.com  5817
# 13                  http://www.redclouds.com  5967
# 14              http://www.oudessentials.com  5977
# 15                 http://www.secondlife.com  5816
# 16                    http://vigo-online.com  5047
# 17   http://www.bookdrivingtestaustralia.com  8299
# 18             http://getexcellenthealth.com  5499
# 23                    http://www.ecosway.com  5999
# 24                http://www.gemblygames.com  7994
# 27           http://www.en.porno-eigakan.com  5967
# 28          http://www.cachecoeurlingerie.us  5631
# 29                 http://www.milfpoking.com  5967
# 31                  http://18babysitters.com  5967
# 34                     http://zoomtrader.com  6211
# 35                http://www.broadcust.co.il  5968
# 37              http://www.uklotterylive.com  7995
# 38                  http://www.getcbdpet.com  5499
# 39                    http://disgraced18.com  5967
# 43                    http://www.justfly.com  4722
# 44                       http://www.10bet.ie  7995
# 46             http://slotsjackpotcasino.com  7995
# 48                    http://funandbingo.com  7995
# ..                                       ...   ...
# 442                    http://bubbibingo.com  7995
# 449                  http://www.en.007ch.com  5967
# 450                 http://vcloud.vasayo.com  5969
# 452                http://www.bombagames.com  7995
# 454                     http://bingokong.net  7995
# 457                  http://www.manyvids.com  5967
# 458                    http://secretdate.com  7273
# 459                   http://SlutCentral.com  5967
# 460              http://www.BestWebVault.com  4816
# 462          http://www.maleimage-shop.co.uk  5611
# 463                   http://www.paywith.com  6012
# 464                http://www.gsimarkets.com  6211
# 465                 http://www.sheinside.com  5631
# 466              http://main.balletbingo.com  7995
# 467                  http://massagecreep.com  5967
# 468                     http://www.uxpin.com  7372
# 469                    http://kellybingo.com  7995
# 473               http://www.hubfootwear.com  5661
# 476                     http://www.fhtpay.hk  5732
# 477             http://www.pharmahorse.co.uk  5499
# 479            http://www.PracticeWealth.com  8999
# 481                      http://gggdevot.com  5967
# 484                      http://pushplay.com  7841
# 485                  http://www.brazzers.com  5967
# 486                http://flirtinginside.com  7273
# 488                  http://www.gamelink.com  5967
# 489                   http://www.soufeel.com  5631
# 491                  http://crueltyparty.com  5967
# 493                http://www.big5casino.com  7995
# 494                 http://www.finitro.co.nz  5499
#
#                                                content taal
# 0    Sorry  your browser doesn't support JavaScript...   en
# 1    Register  Forgot password?\r\n\r\n  * GAMES\r\...   en
# 2    Login Forgot Password\r\n\r\nToggle navigation...   en
# 4    Language : __\r\n\r\n  * English\r\n  * 日本語\r\...   en
# 5    Login or Create an account.\r\n\r\nWish List \...   en
# 7      * Member Login\r\n\r\nX\r\n\r\nUsername\r\n\...   en
# 10   Skip to content\r\n\r\nDezzel\r\n\r\nGame Chan...   en
# 11   ### Error. Page cannot be displayed. Please co...   en
# 12   **SUPPORT 7 DAYS A WEEK**\r\n\r\nPHONE  EMAIL ...   en
# 13     * Explicit RedClouds\r\n  * Free VoyeurWeb\r...   en
# 14   0\r\n\r\n  * Home\r\n  * About Us\r\n  * Dual ...   en
# 15     * Language \r\n    * English\r\n    * 日本語\r\...   en
# 16     * __ My Account\r\n    * Register\r\n    * L...   en
# 17     *   *   * \r\n\r\nHome About FAQs Terms Cont...   en
# 18   # Marconi Health Products\r\n\r\n## Introducin...   en
# 23   |   |  \r\n---|---|---  \r\n  |  |  Home  |  A...   en
# 24   #  Gembly Games\r\n\r\n  * Home\r\n  * About\r...   en
# 27   Warning: The following web site is intended fo...   en
# 28     * # Nursing Bras  Maternity Swimwear  Matern...   en
# 29   ---  \r\nHome | Member Login | Site Terms | Pr...   en
# 31   bookmark us\!\r\n\r\n  *   *   *   *   * \r\n\...   en
# 34   ×\r\n\r\n####\r\n\r\n* * *\r\n\r\n* * *\r\n\r\...   en
# 35     \r\n\r\n\{\{locale.day + ' '\}\} \{\{ now\(\...   en
# 37   |  |  \r\n  \r\n---  \r\nUK Lottery |  | About...   en
# 38   What Is CBD _Pet_ How It Works Success Stories...   en
# 39   #\r\n\r\n  * Home \(current\)\r\n  * Members L...   en
# 43     * Hello  guest \r\n\r\n    * Sign In\r\n    ...   en
# 44   10Bet\r\n\r\nLoginJoin\r\n\r\n10Bet\r\n\r\nMy ...   en
# 46     * HOME\r\n  * PROMOTIONS\r\n  * GAMES\r\n  *...   en
# 48   # FunAndBingo\r\n\r\nUsername\r\n\r\nPassword\...   en
# ..                                                 ...  ...
# 442  # BubbiBingo\r\n\r\nUsername\r\n\r\nPassword\r...   en
# 449  Enter only if you are an adult and agree to th...   en
# 450  Toggle Navigation\r\n\r\n#### Vasayo\r\n\r\n  ...   en
# 452  ﻿\r\n\r\n#  bombagames.com\r\n\r\n* * *\r\n\r\...   en
# 454  Login Forgot Password\r\n\r\nToggle navigation...   en
# 457    * Vids\r\n  * MV Stars\r\n  * Daily\r\n  * C...   en
# 458  **WARNING\!\!** Secretdate.com uses JavaScript...   en
# 459  **SlutCentral.Com** Brings you **_The Hottest ...   en
# 460  **Best Web Vault**\r\n\r\n  * Home\r\n  * Over...   en
# 462  Sign in\r\n\r\nContact us\r\n\r\n__ORDERLINE M...   en
# 463    *   *   * \r\n\r\n# 100 - 200 Granville Stre...   en
# 464    * My Account\r\n  * Forgot Password\r\n\r\nE...   en
# 465  \{\{timeArray\[index\].hour\}\} _H_ \{\{timeAr...   en
# 466  Login Forgot Password\r\n\r\nToggle navigation...   en
# 467  #\r\n\r\n  * Home \(current\)\r\n  * Members L...   en
# 468    * Features\r\n    * UXPin Prototyping\r\n   ...   en
# 469  Login Forgot Password\r\n\r\nToggle navigation...   en
# 473  **FREE  SHIPPING **  **in  EU  **for  orders  ...   en
# 476    * Home\r\n  * About\r\n  * Support\r\n\r\n  ...   en
# 477  **JavaScript seems to be disabled in your brow...   en
# 479  Chiropractic Coaching  Chiropractic Seminars  ...   en
# 481    \r\n**Notice** : Undefined index: HTTP\_ACCE...   en
# 484  Questions?  \r\nContact Support\r\n\r\nMember ...   en
# 485    *   * _Join Now_\r\n  * _Members Login_\r\n\...   en
# 486  Javascript is disabled on your browser. Please...   en
# 488  This site requires JavaScript to function. Ple...   en
# 489  __\r\n\r\nConfirm\r\n\r\n__\r\n\r\n__\r\n\r\n_...   en
# 491  #\r\n\r\n  * Home \(current\)\r\n  * Members L...   en
# 493  # Big5Casino\r\n\r\n__\r\n\r\n  * English \r\n...   en
# 494  **JavaScript seems to be disabled in your brow...   en
#
# [296 rows x 4 columns]

# %% [markdown]
# #### Apply clean_data to dataset

# %%
f = open("text_content_web2_processed.txt", "w", encoding="utf-8")
i = 0
for row in documents_en.iterrows():
    web = row[1].website
    content = clean_data(row[1].content)
    mcc = row[1].mcc
    cluster = row[1].cluster
    taal = row[1].taal
    print(web)
    f.write('%s, %s, %s, %s, %s\n' % (web, mcc, taal, cluster,content))
# Out:
# balloon  2018-12-18 12:08:57.382927
# http://www.max-c-e.com
# balloon  2018-12-18 12:08:57.450775
# http://www.tradacasino.com
# balloon  2018-12-18 12:08:57.486679
# http://bensbingo.com
# balloon  2018-12-18 12:08:57.736030
# http://towa-esutenet.com
# balloon  2018-12-18 12:09:04.949346
# http://www.mi-porn.com
# balloon  2018-12-18 12:09:04.999201
# http://getdownxxx.com
# balloon  2018-12-18 12:09:05.042087
# http://www.dezzel.com
# balloon  2018-12-18 12:09:05.043084
# http://mycharitybingo.com
# balloon  2018-12-18 12:09:05.051062
# http://www.Resumenow.com
# balloon  2018-12-18 12:09:05.149811
# http://www.redclouds.com
# balloon  2018-12-18 12:09:05.161780
# http://www.oudessentials.com
# balloon  2018-12-18 12:09:05.351302
# http://www.secondlife.com
# balloon  2018-12-18 12:09:05.360279
# http://vigo-online.com
# balloon  2018-12-18 12:09:05.426886
# http://www.bookdrivingtestaustralia.com
# balloon  2018-12-18 12:11:34.971517
# http://cockfortwo.com
# balloon  2018-12-18 12:11:35.218456
# http://www.eezypeezyparties.com/
# balloon  2018-12-18 12:11:35.218456
# http://deepthroatlove.com
# balloon  2018-12-18 12:11:35.234077
# http://www.devoteddating.com
# balloon  2018-12-18 12:11:35.234077
# http://www.magicfling.com
# balloon  2018-12-18 12:11:35.334803
# http://www.servicedletsgroup.com
# balloon  2018-12-18 12:11:35.826694
# http://www.medicadepot.com
# balloon  2018-12-18 12:11:35.834523
# http://pornpros.com
# balloon  2018-12-18 12:11:35.834523
# http://www.fuckpath.com
# balloon  2018-12-18 12:11:35.890540
# http://www.vipauction.co.uk
# balloon  2018-12-18 12:11:36.057426
# http://cinemaden.com
# balloon  2018-12-18 12:11:36.216728
# http://budapesthardcore.com
# balloon  2018-12-18 12:11:36.232352
# http://www.maharishi.ca
# balloon  2018-12-18 12:11:36.275624
# http://www.compassplus.com
# balloon  2018-12-18 12:11:36.363532
# http://www.made.com
# balloon  2018-12-18 12:11:36.375566
# http://www.daringlegend.com
# balloon  2018-12-18 12:11:36.375566
# http://www.gayfuckbud.com
# balloon  2018-12-18 12:11:36.553975
# http://pubavip.com
# balloon  2018-12-18 12:11:36.623280
# http://reelvidz.com
# balloon  2018-12-18 12:11:37.308273
# http://bluelions-casino.com
# balloon  2018-12-18 12:11:37.323896
# http://bubbibingo.com
# balloon  2018-12-18 12:11:37.323896
# http://www.en.007ch.com
# balloon  2018-12-18 12:11:37.355169
# http://vcloud.vasayo.com
# balloon  2018-12-18 12:11:37.355169
# http://www.bombagames.com
# balloon  2018-12-18 12:11:37.394417
# http://bingokong.net
# balloon  2018-12-18 12:11:37.425697
# http://www.manyvids.com
# balloon  2018-12-18 12:11:37.441314
# http://secretdate.com
# balloon  2018-12-18 12:11:37.441314
# http://SlutCentral.com
# balloon  2018-12-18 12:11:37.678158
# http://www.BestWebVault.com
# balloon  2018-12-18 12:11:41.896643
# http://www.maleimage-shop.co.uk
# balloon  2018-12-18 12:11:42.150686
# http://www.paywith.com
# balloon  2018-12-18 12:11:42.419109
# http://www.gsimarkets.com
# balloon  2018-12-18 12:11:42.434726
# http://www.sheinside.com
# balloon  2018-12-18 12:11:42.450348
# http://main.balletbingo.com
# balloon  2018-12-18 12:11:42.460883
# http://massagecreep.com
# balloon  2018-12-18 12:11:42.561182
# http://www.uxpin.com
# balloon  2018-12-18 12:11:42.592460
# http://kellybingo.com
# balloon  2018-12-18 12:11:43.277518
# http://www.hubfootwear.com
# balloon  2018-12-18 12:11:43.293141
# http://www.fhtpay.hk
# balloon  2018-12-18 12:11:44.030508
# http://www.pharmahorse.co.uk
# balloon  2018-12-18 12:11:44.569800
# http://www.PracticeWealth.com
# balloon  2018-12-18 12:11:44.705828
# http://gggdevot.com
# balloon  2018-12-18 12:11:44.768301
# http://pushplay.com
# balloon  2018-12-18 12:11:44.864252
# http://www.brazzers.com
# balloon  2018-12-18 12:11:44.879843
# http://flirtinginside.com
# balloon  2018-12-18 12:11:44.890586
# http://www.gamelink.com

# %%
#documents_en["content"] = documents_en["content"].apply(clean_data)

# %%
c= documents_en.content[5]

