# %% [markdown]
# ## Preprocess raw web content

# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import nltk
from langdetect import detect
import re, string, unicodedata
import contractions
import inflect
from bs4 import BeautifulSoup
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer
import datetime

# %% [markdown]
# #### Cleanin text content

# %%
def remove_non_ascii(words):

    """Remove non-ASCII characters from list of tokenized words"""

    new_words = []

    for word in words:

        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')

        new_words.append(new_word)

    return new_words


def remove_punctuation(words):

    """Remove punctuation from list of tokenized words"""

    new_words = []

    for word in words:

        new_word = re.sub(r'[^\w\s]', ' ', word)

        if new_word != '' and new_word != " ":

            new_words.append(new_word)

    return new_words



stop_words = stopwords.words('english')

def remove_stopwords(doc):

    """Remove stop words from list of tokenized words"""
    for word in stop_words:
      
        doc = doc.replace(" "+word+" ", ' ')
        
    return doc



def stem_words(words):

    """Stem words in list of tokenized words"""

    stemmer = LancasterStemmer()

    stems = []

    for word in words:

        stem = stemmer.stem(word)

        stems.append(stem)

    return stems



def lemmatize_verbs(words):

    """Lemmatize verbs in list of tokenized words"""

    lemmatizer = WordNetLemmatizer()

    lemmas = []

    for word in words:

        lemma = lemmatizer.lemmatize(word, pos='v')

        lemmas.append(lemma)

    return lemmas

def isLatin(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

    
def clean_data(content):
    content_str = str(content)   #convert content from object type to string
    words = word_tokenize(content_str)
    
    print("tokenized")
    
    #remove digits, lowercase words
    words = [''.join([i.lower() for i in w if not i.isdigit()]) for w in words]
    
    #remove punctuation
    words = remove_punctuation(words)
    print("punctuation")
    
    #remove empty strings
    while '' in words:
        words.remove('')
    
    #remove non ascii
    words = remove_non_ascii(words)
    print("ascii")
    
    #lemmatization
    words = lemmatize_verbs(words)
    print("lemma")
    doc = " ".join(w for w in words)
    
    #remove stop words
    doc = remove_stopwords(doc)
    print("stopwords")
    #remove special characters
    doc = re.sub('[^A-Za-z0-9]+', ' ', doc)
    
    #print("balloon ", datetime.datetime.now() )
    
    return doc

# %% [markdown]
# ### Read mcc2clusters

# %%
mcc2clusters = {}
with open("mcc2cluster") as f:
    lines = f.read().splitlines()
    for line in lines:
        token = line.split(":")
        
        mcc2clusters[int(token[0])] = token[1]

# %%
mcc2clusters[5941]
# Out:
# 'marketplace1'

# %% [markdown]
# ## read raw content & process

# %%
def process_raw_content(fname, i):   
    ## Read text file
    #fname = 'raw_content/text_content_web'
    filename = fname + i + ".txt"

    with open(filename, 'r', encoding="utf-8") as myfile:
        data = myfile.read()
    myfile.close()


    ## split into websites
    document = data.split("\n\nNEW WEBSITE\n\n") 

    ##create list of dataframe columns
    website = []
    content = []
    mcc = []

    for doc in document:
        splitted = doc.split(",")
        if len(splitted) >= 3:
            website.append(splitted[0][1:])
            mcc.append(int(splitted[1]))
            content.append(" ".join(splitted[2:]))

    docs = {'website': website ,'mcc': mcc,  'content': content}

    documents = pd.DataFrame(docs, columns = ['website', 'mcc', 'content'])

    print("Dataframe created")

    ## Add Language Column

    taal = []

    for row in documents.iterrows():
        try:
            taal.append(detect(row[1].content))
            #print(detect(row[1].content))
        except:
            taal.append("none")

    df = pd.DataFrame(taal)
    df = df.rename(columns={0: "taal"})
    docs = pd.concat([documents, df], axis=1, sort=False)

    print("Language column added")

    clusters = []

    for row in docs.iterrows():
        code = int(row[1].mcc)
        #print(code)
        try:
            cluster = mcc2clusters[code]
            clusters.append(cluster)
        except:
            #print(code, "unknown")
            clusters.append("unknown")

    #Add cluster column to dataset

    df = pd.DataFrame(clusters)
    df = df.rename(columns={0: "cluster"})
    docs = pd.concat([docs, df], axis=1, sort=False)

    print("Cluster column added")


    documents_en = docs[docs.taal == "en"]
    #return documents_en
    print("english websites: ", len(documents_en))
    
    
    f = open(fname+i+"processed.txt", "w", encoding="utf-8")
    j = 0
    for row in documents_en.iterrows():
        web = row[1].website
        content = clean_data(row[1].content)
        mcc = row[1].mcc
        #cluster = row[1].cluster
        taal = row[1].taal
        f.write('%s, %s, %s, %s\n' % (web, mcc, taal,content))
        print(web, j)
        j+=1
        
    f.close()

# %%
process_raw_content("raw_content/silver_data/attraction-content", "")
# Out:
# Dataframe created
# Language column added
# Cluster column added
# english websites:  37
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://boatamsterdam.com/en/ 0
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.lindbergh.nl/ 1
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.feyenoord.com/tickets/tour-tickets 2
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://tickets.heinekenexperience.com/ 3
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.johancruijffarena.nl/stadiumtour/tour/visitors-information.htm 4
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://tickets.holland.com/en/tours/anne-frank-tour/ 5
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://amsterdamlightfestival.com/en/book-a-tour 6
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.splashtours.nl/en/tickets-prices/ 7
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.bigbustours.com/en/sydney/sydney-tour-tickets-and-passes/sydney-bus-tours/ 8
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://irishtourtickets.com/ 9
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.vredespaleis.nl/visit/guided-tours/?lang=en 10
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.alcatrazcruises.com/tour-options/day-tour/ 11
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://hollandpass.com/pick-up-locations/ 12
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.tours-tickets.com/en 13
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://amsterdamcanalcruises.nl/ 14
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.vangoghmuseum.nl/en 15
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.rijksmuseum.nl/en/ 16
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://astrology.com.au/psychic-readings/fortune-telling 17
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.psychicguild.com/fortune-telling/ 18
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.kasamba.com/fortune-telling/ 19
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.duinrell.com/amusement-park 20
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.efteling.com/en 21
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.ticketmaster.nl/?language=en-us 22
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.seetickets.com/ 23
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.expedia.com/event-tickets/ 24
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.viagogo.com/ 25
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.viagogo.com/Amsterdam/Concert-Tickets 26
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.livenation.co.uk/event/allevents 27
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.eventticketscenter.com/ 28
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.viagogo.com/Concert-Tickets 29
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.songkick.com/ 30
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.ticketmaster.co.uk/section/concerts 31
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.concertgebouw.nl/en/concerts-tickets 32
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.livenation.asia/ 33
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://totoofficial.com/events/ 34
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://premier.ticketek.com.au/ 35
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# https://www.livenation.com.au/ 36

# %%
documents_en = documents_en.reset_index()

# %%
f = open("raw_content/text_content_web"+"8"+"processed_2.txt", "w", encoding="utf-8")
j = 0
for row in documents_en.iterrows():
    if row[0] > 42:
        web = row[1].website
        content = clean_data(row[1].content)
        mcc = row[1].mcc
        #cluster = row[1].cluster
        taal = row[1].taal
        f.write('%s, %s, %s, %s\n' % (web, mcc, taal,content))
        print(web, j)
        j+=1
f.close()
# Out:
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.newchic.com 0
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.taylorgowns.de.com 1
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.vmx-racing.com 2
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.reelhd.com 3
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.airyexpo.com 4
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.faerydress.com 5
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.privatecheatz.com 6
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.auhl.com.hk 7
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.singpet.com 8
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.lightinthebox.com 9
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.dressonlinemall.com 10
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.digimatchy.com 11
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.pomeet.top 12
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.fantasyhairbuy.com 13
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.kerrywines.com 14
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.ericdress.com 15

# %%
for row in r.iterrows():
    if row[0] >= 85:
        web = row[1].website
        content = clean_data(row[1].content)
        mcc = row[1].mcc
        #cluster = row[1].cluster
        taal = row[1].taal
        print(web)
# Out:
# tokenized
# punctuation
# ascii
# lemma
# stopwords
# http://www.slh.com

# %% [markdown]
# #### Reading preprocessed data

# %%
def read_processed(fname, i):
    filename = fname + i + "processed.txt"
    
    with open(filename, 'r', encoding="utf-8") as myfile:
        lines = myfile.readlines()
    myfile.close()
    
    website = []
    mcc = []
    #cluster = []
    taal = []
    content = []
    
    #print(lines[1].split(", ")[4])
    
    for line in lines:
        splitted = line.split(", ")
        website.append(splitted[0])
        mcc.append(splitted[1])
        taal.append(splitted[2])
        #cluster.append(splitted[3])
        content.append(" ".join(splitted[3:]))
    
    docs = {'website': website ,'mcc': mcc,  "taal" : taal, 'content': content}

    documents = pd.DataFrame(docs, columns = ['website', 'mcc', "taal", 'content'])
    
    return documents

# %%
# d = read_processed("raw_content/text_content_web", "")
# print("d")
# d2 = read_processed("raw_content/text_content_web", "2")
# d2 = d.append(d2, ignore_index=True)
# print("d2")
# d3 = read_processed("raw_content/text_content_web", "3")
# print("d3")
# d3 = d2.append(d3, ignore_index=True)
# d4 = read_processed("raw_content/text_content_web", "4")
# print("d4")
# d4 = d3.append(d4, ignore_index=True)
# d5 = read_processed("raw_content/text_content_web", "5")
# print("d5")
# d5 = d4.append(d5, ignore_index=True)
# d6 = read_processed("raw_content/text_content_web", "6")
# print("d6")
# d6 = d5.append(d6, ignore_index=True)
# d7 = read_processed("raw_content/text_content_web", "7")
# print("d7")
# d7 = d6.append(d7, ignore_index=True)
# d8 = read_processed("raw_content/text_content_web", "8")
# print("d8")
# d8 = d7.append(d8, ignore_index=True)

# %%
d = read_processed("raw_content/silver_data/attraction-content", "")
d
# Out:
#                                               website   mcc taal  \
# 0                       https://boatamsterdam.com/en/  7991   en
# 1                           https://www.lindbergh.nl/  7991   en
# 2      https://www.feyenoord.com/tickets/tour-tickets  7991   en
# 3             https://tickets.heinekenexperience.com/  7991   en
# 4   https://www.johancruijffarena.nl/stadiumtour/t...  7991   en
# 5   https://tickets.holland.com/en/tours/anne-fran...  7991   en
# 6   https://amsterdamlightfestival.com/en/book-a-tour  7991   en
# 7       https://www.splashtours.nl/en/tickets-prices/  7991   en
# 8   https://www.bigbustours.com/en/sydney/sydney-t...  7991   en
# 9                       https://irishtourtickets.com/  7991   en
# 10  https://www.vredespaleis.nl/visit/guided-tours...  7991   en
# 11  https://www.alcatrazcruises.com/tour-options/d...  7991   en
# 12         https://hollandpass.com/pick-up-locations/  7991   en
# 13                   https://www.tours-tickets.com/en  7991   en
# 14                  https://amsterdamcanalcruises.nl/  7991   en
# 15                    https://www.vangoghmuseum.nl/en  7991   en
# 16                     https://www.rijksmuseum.nl/en/  7991   en
# 17  https://astrology.com.au/psychic-readings/fort...  7996   en
# 18      https://www.psychicguild.com/fortune-telling/  7996   en
# 19           https://www.kasamba.com/fortune-telling/  7996   en
# 20            https://www.duinrell.com/amusement-park  7996   en
# 21                        https://www.efteling.com/en  7996   en
# 22        https://www.ticketmaster.nl/?language=en-us  7922   en
# 23                        https://www.seetickets.com/  7922   en
# 24             https://www.expedia.com/event-tickets/  7922   en
# 25                           https://www.viagogo.com/  7922   en
# 26  https://www.viagogo.com/Amsterdam/Concert-Tickets  7922   en
# 27       https://www.livenation.co.uk/event/allevents  7922   en
# 28                https://www.eventticketscenter.com/  7922   en
# 29            https://www.viagogo.com/Concert-Tickets  7922   en
# 30                          https://www.songkick.com/  7922   en
# 31    https://www.ticketmaster.co.uk/section/concerts  7922   en
# 32   https://www.concertgebouw.nl/en/concerts-tickets  7922   en
# 33                       https://www.livenation.asia/  7922   en
# 34                    http://totoofficial.com/events/  7922   en
# 35                   https://premier.ticketek.com.au/  7922   en
# 36                     https://www.livenation.com.au/  7922   en
#
#                                               content
# 0   houseboats canal cruise eng nl book find us bo...
# 1   lindbergh tour operators group contact holland...
# 2   x fanshop naar feyenoord nl menu fanshop naar ...
# 3   you use old browser please update browser view...
# 4   en arena mobility portal inside arena login ti...
# 5    search exact match search title search conten...
# 6   festival artworks stories organisation call co...
# 7   nl en de search search would rather speak some...
# 8    big bus tours ticket select day edit total au...
# 9   giants causeway tour game throne tour tour en ...
# 10  jurisdiction international court justice perma...
# 11  skip main content travel advisory alcatraz tim...
# 12  how work museums attractions tour train ticket...
# 13  eur en save cart countryside windmills tour du...
# 14   things english nederlands canal cruise tour m...
# 15  to offer even information museum vincent van g...
# 16  ticket search website work clear language engl...
# 17   home astrology astrology technique astrology ...
# 18  skip content call psychic log sign psychics lo...
# 19  sign register work service center psychic read...
# 20  holiday park holiday park accommodation holida...
# 21  contact directions login en nl de fr zh discov...
# 22  nlen gift cardservice contactplatinum ticket m...
# 23  import favourite artists receive email alert g...
# 24  customer support feedback shop travel home bun...
# 25  this site use cookies provide great user exper...
# 26  this site use cookies provide great user exper...
# 27  search login register concert events festivals...
# 28   sport concacaf gold cup box fight exhibition ...
# 29  this site use cookies provide great user exper...
# 30  amsterdam concert popular ticket amsterdam ams...
# 31  ukall unite kingdom gift cardsoffershelp music...
# 32  we use cookies optimise website provide target...
# 33  search login register concert events festivals...
# 34  trip around sun tour sale buy ticket order new...
# 35  our home page match region get see near change...
# 36  search login register concert events festivals...

# %%
media = pd.read_csv("media.csv")

# %%
clusters = []
for row in d.iterrows():
    code = int(row[1].mcc)
    #print(code)
    try:
        cluster = mcc2clusters[code]
        clusters.append(cluster)
    except:
        print(code, "unknown")
        clusters.append("unknown")

#Add cluster column to dataset

df = pd.DataFrame(clusters)
df = df.rename(columns={0: "cluster"})
docs = pd.concat([d, df], axis=1, sort=False)

print("Cluster column added")
# Out:
# Cluster column added

# %%
docs
# Out:
#                                               website   mcc taal  \
# 0                       https://boatamsterdam.com/en/  7991   en
# 1                           https://www.lindbergh.nl/  7991   en
# 2      https://www.feyenoord.com/tickets/tour-tickets  7991   en
# 3             https://tickets.heinekenexperience.com/  7991   en
# 4   https://www.johancruijffarena.nl/stadiumtour/t...  7991   en
# 5   https://tickets.holland.com/en/tours/anne-fran...  7991   en
# 6   https://amsterdamlightfestival.com/en/book-a-tour  7991   en
# 7       https://www.splashtours.nl/en/tickets-prices/  7991   en
# 8   https://www.bigbustours.com/en/sydney/sydney-t...  7991   en
# 9                       https://irishtourtickets.com/  7991   en
# 10  https://www.vredespaleis.nl/visit/guided-tours...  7991   en
# 11  https://www.alcatrazcruises.com/tour-options/d...  7991   en
# 12         https://hollandpass.com/pick-up-locations/  7991   en
# 13                   https://www.tours-tickets.com/en  7991   en
# 14                  https://amsterdamcanalcruises.nl/  7991   en
# 15                    https://www.vangoghmuseum.nl/en  7991   en
# 16                     https://www.rijksmuseum.nl/en/  7991   en
# 17  https://astrology.com.au/psychic-readings/fort...  7996   en
# 18      https://www.psychicguild.com/fortune-telling/  7996   en
# 19           https://www.kasamba.com/fortune-telling/  7996   en
# 20            https://www.duinrell.com/amusement-park  7996   en
# 21                        https://www.efteling.com/en  7996   en
# 22        https://www.ticketmaster.nl/?language=en-us  7922   en
# 23                        https://www.seetickets.com/  7922   en
# 24             https://www.expedia.com/event-tickets/  7922   en
# 25                           https://www.viagogo.com/  7922   en
# 26  https://www.viagogo.com/Amsterdam/Concert-Tickets  7922   en
# 27       https://www.livenation.co.uk/event/allevents  7922   en
# 28                https://www.eventticketscenter.com/  7922   en
# 29            https://www.viagogo.com/Concert-Tickets  7922   en
# 30                          https://www.songkick.com/  7922   en
# 31    https://www.ticketmaster.co.uk/section/concerts  7922   en
# 32   https://www.concertgebouw.nl/en/concerts-tickets  7922   en
# 33                       https://www.livenation.asia/  7922   en
# 34                    http://totoofficial.com/events/  7922   en
# 35                   https://premier.ticketek.com.au/  7922   en
# 36                     https://www.livenation.com.au/  7922   en
#
#                                               content     cluster
# 0   houseboats canal cruise eng nl book find us bo...  attraction
# 1   lindbergh tour operators group contact holland...  attraction
# 2   x fanshop naar feyenoord nl menu fanshop naar ...  attraction
# 3   you use old browser please update browser view...  attraction
# 4   en arena mobility portal inside arena login ti...  attraction
# 5    search exact match search title search conten...  attraction
# 6   festival artworks stories organisation call co...  attraction
# 7   nl en de search search would rather speak some...  attraction
# 8    big bus tours ticket select day edit total au...  attraction
# 9   giants causeway tour game throne tour tour en ...  attraction
# 10  jurisdiction international court justice perma...  attraction
# 11  skip main content travel advisory alcatraz tim...  attraction
# 12  how work museums attractions tour train ticket...  attraction
# 13  eur en save cart countryside windmills tour du...  attraction
# 14   things english nederlands canal cruise tour m...  attraction
# 15  to offer even information museum vincent van g...  attraction
# 16  ticket search website work clear language engl...  attraction
# 17   home astrology astrology technique astrology ...  attraction
# 18  skip content call psychic log sign psychics lo...  attraction
# 19  sign register work service center psychic read...  attraction
# 20  holiday park holiday park accommodation holida...  attraction
# 21  contact directions login en nl de fr zh discov...  attraction
# 22  nlen gift cardservice contactplatinum ticket m...  attraction
# 23  import favourite artists receive email alert g...  attraction
# 24  customer support feedback shop travel home bun...  attraction
# 25  this site use cookies provide great user exper...  attraction
# 26  this site use cookies provide great user exper...  attraction
# 27  search login register concert events festivals...  attraction
# 28   sport concacaf gold cup box fight exhibition ...  attraction
# 29  this site use cookies provide great user exper...  attraction
# 30  amsterdam concert popular ticket amsterdam ams...  attraction
# 31  ukall unite kingdom gift cardsoffershelp music...  attraction
# 32  we use cookies optimise website provide target...  attraction
# 33  search login register concert events festivals...  attraction
# 34  trip around sun tour sale buy ticket order new...  attraction
# 35  our home page match region get see near change...  attraction
# 36  search login register concert events festivals...  attraction

# %%
docs.to_csv("attraction_processed.csv", encoding='utf-8', index=False)

# %%
docs
# Out:
#                         website   mcc taal  \
# 0        https://365playing.com  5815   en
# 1          https://411playz.com  5815   en
# 2        https://777streams.com  5815   en
# 3          https://agamemix.com  5815   en
# 4     https://amazingbundle.com  5815   en
# 5      https://amusicheaven.com  5815   en
# 6        https://backupflix.com  5815   en
# 7           https://beatshd.com  5815   en
# 8      https://bestgamesfun.com  5815   en
# 9        https://bestwebfun.com  5815   en
# 10       https://bundledmix.com  5815   en
# 11       https://cinematrix.net  5815   en
# 12          https://clipfou.com  5815   en
# 13      https://coolgames4u.com  5815   en
# 14         https://dabverse.com  5815   en
# 15        https://dagamebox.com  5815   en
# 16       https://dagamezone.com  5815   en
# 17       https://damusicmix.com  5815   en
# 18        https://fastplayz.com  5815   en
# 19       https://finalblend.com  5815   en
# 20      https://flickheaven.com  5815   en
# 21       https://fun4utoday.com  5815   en
# 22       https://fundrizzle.com  5815   en
# 23      https://fungamesite.com  5815   en
# 24       https://funonfleek.com  5815   en
# 25      https://gamerregion.com  5815   en
# 26       https://gamesuperb.com  5815   en
# 27           https://gamomu.com  5815   en
# 28      https://getfungames.com  5815   en
# 29      https://getmusicmix.com  5815   en
# ..                          ...   ...  ...
# 70         https://playproz.com  5815   en
# 71        https://playwhole.com  5815   en
# 72    https://pressplaygame.com  5815   en
# 73       https://proplayhub.com  5815   en
# 74     https://rapjazzdance.com  5815   en
# 75  https://rocketmarsradio.com  5815   en
# 76     https://rocknrollbox.com  5815   en
# 77       https://savorberry.com  5815   en
# 78        https://smushgame.com  5815   en
# 79       https://songluxury.com  5815   en
# 80        https://songmoose.com  5815   en
# 81          https://soundam.com  5815   en
# 82          https://spoonti.com  5815   en
# 83        https://spotzplay.com  5815   en
# 84          https://starjox.com  5815   en
# 85        https://streamdle.com  5815   en
# 86      https://streammerge.com  5815   en
# 87      https://streamundle.com  5815   en
# 88       https://thegamemix.com  5815   en
# 89    https://themixedbeats.com  5815   en
# 90        https://top-tunes.com  5815   en
# 91       https://topgamemix.com  5815   en
# 92      https://tuneintunes.com  5815   en
# 93       https://tunesilove.com  5815   en
# 94      https://tuneslisten.com  5815   en
# 95     https://tunessurfing.com  5815   en
# 96           https://twindu.com  5815   en
# 97          https://unlifun.com  5815   en
# 98       https://urfavgames.com  5815   en
# 99     https://weenjoymusic.com  5815   en
#
#                                               content        cluster
# 0   play play home register support login unique g...          games
# 1   toggle navigation question email protected log...          games
# 2    home popular price support login signup take ...  entertainment
# 3    simple interface interface easy use anyone na...          games
# 4   amazingbundle home support login join home sup...  entertainment
# 5   please enable js home popular support privacy ...  entertainment
# 6   backupflix flix home music game movies registe...  entertainment
# 7   we open hours day days week contact us telepho...  entertainment
# 8   bestgamesfun home support signup login home su...          games
# 9   please enable js we open hours day days week e...  entertainment
# 10  about feature price bundledmix support login r...  entertainment
# 11  cinematrix en en cs de es pt fr ru tr br sign ...  entertainment
# 12  need support email protected home media price ...  entertainment
# 13   home popular signup support term use privacy ...  entertainment
# 14  dabverse com welcome popular support login sig...          games
# 15  dagamebox home feature popular support sign si...          games
# 16   com menu back home signup support cancel subs...  entertainment
# 17  about popular feature signup support login dam...  entertainment
# 18  toggle navigation question email protected log...  entertainment
# 19  please enable js media one place hot music lis...  entertainment
# 20  home price support login signup feel music fil...  entertainment
# 21  funutoday home support login signup home suppo...  entertainment
# 22  toggle menu home feature statistics bundle gal...          games
# 23  home game price support signup login courage o...  entertainment
# 24  toggle navigation home popular support signup ...  entertainment
# 25  home current box price support login join us t...          games
# 26  toggle navigation home popular support signup ...          games
# 27   home price support login signup start experie...  entertainment
# 28  getfungames home current game price support si...  entertainment
# 29   home genre channel signup member area support...  entertainment
# ..                                                ...            ...
# 70  toggle navigation question email protected log...  entertainment
# 71  sign login support term condition privacy poli...  entertainment
# 72  home feature populare signup support cancel su...  entertainment
# 73   login home popular support signup login home ...          games
# 74   login home register support write us cancel m...  entertainment
# 75  load rocketmarsradio com love music sure rocke...  entertainment
# 76  menu home feature music portable support signu...  entertainment
# 77  toggle navigation home media price register su...  entertainment
# 78  toggle navigation question email protected log...  entertainment
# 79  home login support sign diverse library offer ...  entertainment
# 80  toggle navigation home feature popular support...  entertainment
# 81  home content genres channel support register s...          games
# 82  home price register support login home price r...  entertainment
# 83  toggle navigation question email protected log...  entertainment
# 84  home try popular price register support login ...          games
# 85  the media bundle home feature popular support ...  entertainment
# 86  support signup login intro popular right price...  entertainment
# 87  home support signup login home support signup ...  entertainment
# 88  home current feature game service support logi...  entertainment
# 89  menu dot cross arrow long close navup navdown ...  entertainment
# 90  explore home genre channel price support membe...  entertainment
# 91   feature trend get start login game platform t...          games
# 92  tuneintunes home feature music support sign si...  entertainment
# 93  login register support info contact us forget ...            NaN
# 94  home popular support login signup air today hi...            NaN
# 95  support sign home trend testimonials get start...            NaN
# 96  welcome register support login support term pr...            NaN
# 97  unlifun home price log sign unlimited fun inst...            NaN
# 98  home support signup login shoot race adventure...            NaN
# 99  welcome weenjoymusic com email protected home ...            NaN
#
# [100 rows x 5 columns]
